# %%
import matplotlib.pyplot as plt
import cv2

# %%
img = plt.imread(r"D:\image_processing_practice\DIP_Java\imagingbook_images_de3\ch06\ireland02-orig.tif")

# %%
edges = cv2.Canny(img, 50, 150)

# %%
plt.imshow(edges, cmap="gray")
